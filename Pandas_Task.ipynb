# %% [markdown]
# # Files:
# https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view
#
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv
# https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
df1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt',' ')

# %%
df2
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')

# %%
df3
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df4
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %% [markdown]
# # df1 activities

# %%
df1.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df1.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df1.shape[0]
# Out:
# 4622

# %%
df1.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# #Which was the most ordered item? and How many items were ordered?

# %%
c = df1.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# #What was the most ordered item in the choice_description column

# %%
c = df1.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# Turn Item price into float

# %%
dollar = lambda x: float(x[1:-1])
df1.item_price = df1.item_price.apply(dollar)

# %%
df1.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# How much was the revenue for the period in the dataset?

# %%
revenue = (df1['quantity']* df1['item_price']).sum()
print('Revenue was: $' + str(np.round(revenue,2)))
# Out:
# Revenue was: $39237.02

# %% [markdown]
# print a data frame with only two columns item_name and item_price

# %%
# delete the duplicates in item_name and quantity
filtered = df1.drop_duplicates(['item_name','quantity'])
# select only the products with quantity equals to 1
one_prod = filtered[filtered.quantity == 1]
# select only the item_name and item_price columns
price_per_item = one_prod[['item_name', 'item_price']]
# sort the values from the most to less expensive
price_per_item.sort_values(by = "item_price", ascending = False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %% [markdown]
# #What was the quantity of the most expensive item ordered?

# %%
df1.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# How many times were a veggies salad ordered?

# %%
df1[df1.item_name == "Veggie Salad Bowl"]
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...

# %% [markdown]
# # Activities with df2

# %%
df2.head(5)
# Out:
#           name  calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77

# %% [markdown]
# info of df2

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      20 non-null     object
#  1   calories  20 non-null     int64
#  2   sodium    20 non-null     int64
#  3   alcohol   20 non-null     float64
#  4   cost      20 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 928.0+ bytes

# %%
df2.dtypes
# Out:
# name         object
# calories      int64
# sodium        int64
# alcohol     float64
# cost        float64
# dtype: object

# %%
df2.count()
# Out:
# name        20
# calories    20
# sodium      20
# alcohol     20
# cost        20
# dtype: int64

# %% [markdown]
# Which is costiliest beer among all?

# %%
df2[df2['cost']==max(df2['cost'])]['name']
# Out:
# 14    Kirin
# Name: name, dtype: object

# %% [markdown]
# Name beer with highest and lowest calories

# %%
df2[df2['calories']==max(df2['calories'])]['name']
# Out:
# 6    Augsberger
# Name: name, dtype: object

# %%
df2[df2['calories']==min(df2['calories'])]['name']
# Out:
# 15    Pabst_Extra_Light
# Name: name, dtype: object

# %% [markdown]
# # Names of beer available?

# %%
df2['name'].unique()
# Out:
# array(['Budweiser', 'Schlitz', 'Lowenbrau', 'Kronenbourg', 'Heineken',
#        'Old_Milwaukee', 'Augsberger', 'Srohs_Bohemian_Style',
#        'Miller_Lite', 'Budweiser_Light', 'Coors', 'Coors_Light',
#        'Michelob_Light', 'Becks', 'Kirin', 'Pabst_Extra_Light', 'Hamms',
#        'Heilemans_Old_Style', 'Olympia_Goled_Light', 'Schlitz_Light'],
#       dtype=object)

# %% [markdown]
# Cost of Budweiser?

# %%
df2[df2['name']=='Budweiser']['cost']
# Out:
# 0    0.43
# Name: cost, dtype: float64

# %%
Average Cost of beer?
# Out:
# Object `beer` not found.

# %%
Average Cost of beer

# %%
df2['cost'].mean()
# Out:
# 0.4945000000000001

# %% [markdown]
# Median of Sodium in Beer?

# %%
df2['sodium'].median()
# Out:
# 15.0

# %% [markdown]
# # Activities with df3

# %%
df3.head(5)
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df3.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
df3.describe()
# Out:
#              Year    Population         Total       Violent      Property  \
# count    55.00000  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1987.00000  2.461556e+08  1.060315e+07  1.188806e+06  9.412499e+06
# std      16.02082  4.166216e+07  3.175931e+06  4.597107e+05  2.738512e+06
# min    1960.00000  1.793232e+08  3.384200e+06  2.884600e+05  3.095700e+06
# 25%    1973.50000  2.106215e+08  9.096958e+06  9.253150e+05  8.060014e+06
# 50%    1987.00000  2.422829e+08  1.140151e+07  1.322390e+06  1.018259e+07
# 75%    2000.50000  2.833697e+08  1.308449e+07  1.432762e+06  1.160509e+07
# max    2014.00000  3.188571e+08  1.487290e+07  1.932270e+06  1.296110e+07
#
#              Murder  Forcible_Rape        Robbery  Aggravated_assault  \
# count     55.000000      55.000000      55.000000        5.500000e+01
# mean   17317.236364   72714.800000  416449.890909        6.811818e+05
# std     4267.442664   28278.006893  150506.403782        2.960255e+05
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
df3.count()
# Out:
# Year                  55
# Population            55
# Total                 55
# Violent               55
# Property              55
# Murder                55
# Forcible_Rape         55
# Robbery               55
# Aggravated_assault    55
# Burglary              55
# Larceny_Theft         55
# Vehicle_Theft         55
# dtype: int64

# %% [markdown]
# No of Theft in highest murder city?

# %%
df3[df3['Murder']==max(df3['Murder'])]['Vehicle_Theft']
# Out:
# 31    1661700
# Name: Vehicle_Theft, dtype: int64

# %% [markdown]
# Average Property per Capita?

# %%
df_avg = df3['Population']/df3['Property']

# %%
df_avg.mean()
# Out:
# 28.724396214932675

# %% [markdown]
# Total Population?

# %%
df3['Population'].sum()
# Out:
# 13538557224

# %% [markdown]
# Year with Most robbery?

# %%
df3[df3['Robbery']==max(df3['Robbery'])]['Year']
# Out:
# 31    1991
# Name: Year, dtype: int64

# %% [markdown]
# # Activities with df4

# %%
df4.head(5)
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
df4.dtypes
# Out:
# Package        object
# Item           object
# Title          object
# Rows            int64
# Cols            int64
# n_binary        int64
# n_character     int64
# n_factor        int64
# n_logical       int64
# n_numeric       int64
# CSV            object
# Doc            object
# dtype: object

# %%
df4.describe()
# Out:
#                Rows         Cols     n_binary  n_character     n_factor  \
# count  1.714000e+03  1714.000000  1714.000000  1714.000000  1714.000000
# mean   3.900833e+03    13.086348     1.931155     0.302800     1.270128
# std    3.997025e+04   171.966384    17.416499     1.266075     3.194779
# min    2.000000e+00     1.000000     0.000000     0.000000     0.000000
# 25%    3.400000e+01     3.000000     0.000000     0.000000     0.000000
# 50%    1.055000e+02     5.000000     0.000000     0.000000     0.000000
# 75%    5.847500e+02     9.000000     2.000000     0.000000     2.000000
# max    1.414593e+06  6831.000000   624.000000    17.000000    64.000000
#
#          n_logical    n_numeric
# count  1714.000000  1714.000000
# mean      0.030922    11.429988
# std       0.405278   171.905339
# min       0.000000     0.000000
# 25%       0.000000     2.000000
# 50%       0.000000     3.000000
# 75%       0.000000     7.000000
# max      11.000000  6830.000000

# %% [markdown]
# index categorical columns

# %%
df4.dtypes[df4.dtypes=='object'].index
# Out:
# Index(['Package', 'Item', 'Title', 'CSV', 'Doc'], dtype='object')

# %% [markdown]
# describe categorical columns

# %%
df_cat=df4[df4.dtypes[df4.dtypes=='object'].index]
df_cat.describe()
# Out:
#           Package     Item                       Title  \
# count        1714     1714                        1714
# unique         53     1658                        1580
# top     Stat2Data  housing  Internal functions for gap
# freq          211        3                          18
#
#                                                       CSV  \
# count                                                1714
# unique                                               1714
# top     https://vincentarelbundock.github.io/Rdatasets...
# freq                                                    1
#
#                                                       Doc
# count                                                1714
# unique                                               1714
# top     https://vincentarelbundock.github.io/Rdatasets...
# freq                                                    1

# %% [markdown]
# package with most rows

# %%
df4[df4['Rows']==max(df4['Rows'])]['Package']
# Out:
# 1157    openintro
# Name: Package, dtype: object

# %% [markdown]
# Getting csv filenames into seperate column

# %%
l =[]
for i in range(0,df4['CSV'].count()):
    l.append(df4.CSV.str.split('/')[i][-1])

# %%
df4['csv_filename']=l

# %%
df4.head(5)
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %% [markdown]
# Getting Doc filenames into seperate column

# %%
l =[]
for i in range(0,df4['Doc'].count()):
    l.append(df4.Doc.str.split('/')[i][-1])
df4['doc_filename']=l

# %%
df4.head(5)
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %% [markdown]
# Drop CSV and Doc columns

# %%
df_new = df4.drop(columns=['CSV','Doc'])

# %%
df_new.head(5)
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#         csv_filename        doc_filename
# 0        Affairs.csv        Affairs.html
# ...
